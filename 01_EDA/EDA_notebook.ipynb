# %%
from sqlalchemy import create_engine
import pandas as pd
from sqlalchemy import text
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem import WordNetLemmatizer
import re
import string
import pickle
from EDA import clean_ratings_dist, clean_ratings_dist_2, clean_gr_description, lower_clean, clean_description, word_tokenize_description, lemmatize_nouns, lemmatize_verbs, lemmatized_column
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/annabradleywebb/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
nltk.download('wordnet')
lemmatizer = nltk.stem.WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/annabradleywebb/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
cnx = create_engine('postgresql://ubuntu@18.222.253.94:5432/books')

# %%
non_bestsellers_query = (''' 
select * from kagglegoodreads 
where description is not null 
and authors not in ('[NOT A BOOK]', '[McGraw-Hill%]')
and title not like '%%McGraw-Hill%%' 
and title not like '%%Instructional%%' 
and title not like '%%Fundamentals of%%' 
and title not like '%%Handbook%%'
and title not like '%%Education%%'
and ratings_count not like '0'
and publisher not like '%%University Press%%'
and authors not like '%%,%%,%%,%%'
and description not like '%%textbook%%'
and description like '%novel%' or description like '%story%'
and description not like '%%education%%'
and description not like '%%teacher%%'
''')

# %%
#Bestsellers df to match non-bestsellers
bestsellers = ('''
select
*
from 
nytgoodreads
''')

# %%
#Bestsellers df with full additional information
bestsellers_join = ('''
select sum("rank") as "sum_of_bestseller_rank", 
min("rank") as "best_nyt_rank", 
max(weeks_on_list) as "total_weeks_on_nyt_list", 
u_nyt_bestsellers.title,
u_nyt_bestsellers.author, 
min(nytgoodreads.description) as "goodreads_description", 
min(u_nyt_bestsellers.description) as "nyt_description",
nytgoodreads.avg_rating as "goodreads_avg_rating",
min(nytgoodreads.publication_date) as "earliest_publication", 
min(nytgoodreads.rating_dist) as "goodreads_rating_dist",
max(nytgoodreads.text_reviews_count) as "goodreads_reviews_count",
min(u_nyt_bestsellers.primary_isbn10) as "isbn_10", 
min(u_nyt_bestsellers.primary_isbn13) as "isbn_13",
case when sunday_review_link is not null then 1 else 0 end as "nyt_sunday_review",
case when book_review_link is not null then 1 else 0 end as "nyt_book_review",
case when first_chapter_link is not null then 1 else 0 end as "nyt_first_chapter_featured",
min("date") as "first_week_on_nyt_list",
max("date") as "last_week_on_nyt_list"
from u_nyt_bestsellers 
inner join nytgoodreads on text(nytgoodreads.isbn13) = u_nyt_bestsellers.primary_isbn13 
group by u_nyt_bestsellers.title, nytgoodreads.avg_rating, u_nyt_bestsellers.author,
"nyt_sunday_review", "nyt_book_review", "nyt_first_chapter_featured"
order by total_weeks_on_nyt_list desc
''')

# %%
bestsellers = pd.read_sql_query(bestsellers, cnx)

# %%
non_bestsellers = pd.read_sql_query(text(non_bestsellers_query), cnx)

# %%
non_bestsellers.shape
# Out:
# (5691, 17)

# %%
bestsellers.shape
# Out:
# (2869, 18)

# %%
non_bestsellers = non_bestsellers.drop(["index"],axis=1)

# %%
non_bestsellers["bestseller"] = 0

# %%
bestsellers["bestseller"] = 1

# %% [markdown]
# Separate rating distributions into columns

# %%
bestsellers = clean_ratings_dist(bestsellers, "rating_dist")

# %%
bestsellers = clean_ratings_dist_2(bestsellers, "rating_dist")

# %%
non_bestsellers = clean_ratings_dist(non_bestsellers, "rating_dist")

# %%
non_bestsellers = clean_ratings_dist_2(non_bestsellers, "rating_dist")

# %% [markdown]
# Take out HTML elements

# %%
bestsellers = clean_gr_description(bestsellers, "description")
# Out:
# /Users/annabradleywebb/PycharmProjects/Project5/EDA/EDA.py:34: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 34 of the file /Users/annabradleywebb/PycharmProjects/Project5/EDA/EDA.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(df[description_column][i])
# /Users/annabradleywebb/PycharmProjects/Project5/EDA/EDA.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[description_column][i] = soup.get_text()

# %%
non_bestsellers = clean_gr_description(non_bestsellers, "description")

# %% [markdown]
# Remove non-alphabet characters and make text lowercase

# %%
bestsellers = clean_description(bestsellers, "description")
# Out:
# /Users/annabradleywebb/PycharmProjects/Project5/EDA/EDA.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[description_column][i] = lower_clean(df[description_column][i])

# %%
non_bestsellers = clean_description(non_bestsellers, "description")

# %%
bestsellers = clean_description(bestsellers, "title")

# %%
non_bestsellers = clean_description(non_bestsellers, "title")

# %% [markdown]
# Preparing for NLP on Goodreads description

# %%
bestsellers = word_tokenize_description(bestsellers, "description")
# Out:
# /Users/annabradleywebb/PycharmProjects/Project5/EDA/EDA.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['word_tokenized_description'][i] = nltk.word_tokenize(df[text][i])
# /Users/annabradleywebb/anaconda3/envs/metis/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
non_bestsellers = word_tokenize_description(non_bestsellers, "description")

# %%
bestsellers = lemmatized_column(bestsellers)
# Out:
# /Users/annabradleywebb/PycharmProjects/Project5/EDA/EDA.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lemmatized_description'][i] = lemmatize_nouns(df['word_tokenized_description'][i])
# /Users/annabradleywebb/PycharmProjects/Project5/EDA/EDA.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lemmatized_description'][i] = lemmatize_verbs(df['lemmatized_description'][i])
# /Users/annabradleywebb/PycharmProjects/Project5/EDA/EDA.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lemmatized_description'][i] = ' '.join(df['lemmatized_description'][i])

# %%
non_bestsellers = lemmatized_column(non_bestsellers)

# %%
bestsellers
# Out:
#       index       gid                                             title  \
# 0         0   7361506                 alone  detective d d  warren
# 1         0  10130768                                         tick tock
# 2         0   6620989  the girl with the dragon tattoo  millennium
# 3         0   7654769                               water for elephants
# 4         0   6652906    the girl who played with fire  millennium
# ...     ...       ...                                               ...
# 2864      0  51180570                                     hello  summer
# 2865      0  52383564        network effect  the murderbot diaries
# 2866      0  52879371                                   the   th victim
# 2867      0  53419239                                    the last trial
# 2868      0  52755548                                        big summer
#
#                                   authors  \
# 0                          [Lisa Gardner]
# 1     [James Patterson, Michael Ledwidge]
# 2            [Stieg Larsson, Reg Keeland]
# 3                            [Sara Gruen]
# 4            [Stieg Larsson, Reg Keeland]
# ...                                   ...
# 2864                   [Mary Kay Andrews]
# 2865                       [Martha Wells]
# 2866     [James Patterson, Maxine Paetro]
# 2867                        [Scott Turow]
# 2868                    [Jennifer Weiner]
#
#                                             description  avg_rating  \
# 0     bonus  this edition includes the full text of ...        3.96
# 1     nyc s    detective  michael bennett  has a hug...        4.05
# 2     a spellbinding amalgam of murder mystery  fami...        4.13
# 3     over            copies in print worldwide    n...        4.09
# 4     part blistering espionage thriller  part rivet...        4.24
# ...                                                 ...         ...
# 2864  new york times bestselling author and queen of...        4.18
# 2865  you know that feeling when you re at work  and...        4.61
# 2866  three victims  three bullets  three cities  th...        4.21
# 2867  in this explosive legal thriller from new york...        4.11
# 2868  the    new york times bestselling author of th...        3.79
#
#       ratings_count  text_reviews_count  num_pages  \
# 0               106                  32      324.0
# 1                47                   8        NaN
# 2             15960                3083      429.0
# 3              1749                 311      292.0
# 4              6407                 773      471.0
# ...             ...                 ...        ...
# 2864           1151                 356      558.0
# 2865             65                  21      352.0
# 2866            942                  98        NaN
# 2867              3                   1      485.0
# 2868           6985                1568        NaN
#
#                                         popular_shelves  ...  \
# 0     [to-read, currently-reading, mystery, lisa-gar...  ...
# 1     [to-read, currently-reading, james-patterson, ...  ...
# 2     [to-read, currently-reading, fiction, mystery,...  ...
# 3     [to-read, currently-reading, fiction, favorite...  ...
# 4     [to-read, currently-reading, fiction, mystery,...  ...
# ...                                                 ...  ...
# 2864  [to-read, currently-reading, netgalley, fictio...  ...
# 2865  [to-read, currently-reading, science-fiction, ...  ...
# 2866  [to-read, currently-reading, james-patterson, ...  ...
# 2867  [to-read, currently-reading, fiction, mystery,...  ...
# 2868  [to-read, currently-reading, fiction, chick-li...  ...
#
#                                                    link bestseller   5-star  \
# 0     https://www.goodreads.com/book/show/7361506-alone          1    15893
# 1     https://www.goodreads.com/book/show/10130768-t...          1     8334
# 2     https://www.goodreads.com/book/show/6620989-th...          1  1136433
# 3     https://www.goodreads.com/book/show/7654769-wa...          1   528848
# 4     https://www.goodreads.com/book/show/6652906-th...          1   350054
# ...                                                 ...        ...      ...
# 2864  https://www.goodreads.com/book/show/51180570-h...          1      817
# 2865  https://www.goodreads.com/book/show/52383564-n...          1     3951
# 2866  https://www.goodreads.com/book/show/52879371-t...          1     1678
# 2867  https://www.goodreads.com/book/show/53419239-t...          1      431
# 2868  https://www.goodreads.com/book/show/52755548-b...          1     1957
#
#       4-star  3-star  2-star 1-star    total  \
# 0      21149   11622    2035    696    51395
# 1       9946    4980     783    172    24215
# 2     845761  355379  106672  75936  2520181
# 3     499656  236299   57872  19760  1342435
# 4     307130  106664   18618   6123   788589
# ...      ...     ...     ...    ...      ...
# 2864     936     314      38     16     2121
# 2865    1580     293      28      7     5859
# 2866    1353     619      98     28     3776
# 2867     362     161      53     18     1025
# 2868    4256    2551     491    118     9373
#
#                              word_tokenized_description  \
# 0     [bonus, this, edition, includes, the, full, te...
# 1     [nyc, s, detective, michael, bennett, has, a, ...
# 2     [a, spellbinding, amalgam, of, murder, mystery...
# 3     [over, copies, in, print, worldwide, new, york...
# 4     [part, blistering, espionage, thriller, part, ...
# ...                                                 ...
# 2864  [new, york, times, bestselling, author, and, q...
# 2865  [you, know, that, feeling, when, you, re, at, ...
# 2866  [three, victims, three, bullets, three, cities...
# 2867  [in, this, explosive, legal, thriller, from, n...
# 2868  [the, new, york, times, bestselling, author, o...
#
#                                  lemmatized_description
# 0     bonus this edition include the full text of th...
# 1     nyc s detective michael bennett ha a huge prob...
# 2     a spellbind amalgam of murder mystery family s...
# 3     over copy in print worldwide new york time bes...
# 4     part blister espionage thriller part rivet pol...
# ...                                                 ...
# 2864  new york time bestselling author and queen of ...
# 2865  you know that feel when you re at work and you...
# 2866  three victim three bullet three city the shoot...
# 2867  in this explosive legal thriller from new york...
# 2868  the new york time bestselling author of the no...
#
# [2869 rows x 26 columns]

# %%
non_bestsellers.to_pickle('non_bestsellers.pkl')

# %%
bestsellers.to_pickle('bestsellers.pkl')

# %%
all_books = pd.concat([bestsellers, non_bestsellers])

# %%
all_books
# Out:
#       index       gid                                              title  \
# 0       0.0   7361506                  alone  detective d d  warren
# 1       0.0  10130768                                          tick tock
# 2       0.0   6620989   the girl with the dragon tattoo  millennium
# 3       0.0   7654769                                water for elephants
# 4       0.0   6652906     the girl who played with fire  millennium
# ...     ...       ...                                                ...
# 5686    NaN  18123696  the secret of abdu el yezdi  burton   swinburn...
# 5687    NaN  18100299                                          dark city
# 5688    NaN  13529366                                              breed
# 5689    NaN  31806710                defy the dawn  midnight breed
# 5690    NaN  36647211                                        storm glass
#
#                                   authors  \
# 0                          [Lisa Gardner]
# 1     [James Patterson, Michael Ledwidge]
# 2            [Stieg Larsson, Reg Keeland]
# 3                            [Sara Gruen]
# 4            [Stieg Larsson, Reg Keeland]
# ...                                   ...
# 5686          [Mark Hodder, Gerard Doyle]
# 5687                     [F. Paul Wilson]
# 5688           [Chase Novak, Peter Ganim]
# 5689         [Lara Adrian, Hillary Huber]
# 5690                       [Jeff Wheeler]
#
#                                             description avg_rating  \
# 0     bonus  this edition includes the full text of ...       3.96
# 1     nyc s    detective  michael bennett  has a hug...       4.05
# 2     a spellbinding amalgam of murder mystery  fami...       4.13
# 3     over            copies in print worldwide    n...       4.09
# 4     part blistering espionage thriller  part rivet...       4.24
# ...                                                 ...        ...
# 5686  burton   swinburne return in a new series  the...       3.93
# 5687   repairman jack is one of my favorite characte...       4.19
# 5688  critically celebrated novelist scott spencer d...       3.15
# 5689    hours    minutesan immortal warrior must dec...       4.14
# 5690  from the wall street journal bestselling autho...       4.18
#
#      ratings_count text_reviews_count num_pages  \
# 0              106                 32       324
# 1               47                  8       NaN
# 2            15960               3083       429
# 3             1749                311       292
# 4             6407                773       471
# ...            ...                ...       ...
# 5686            14                  2      None
# 5687             8                  0      None
# 5688             7                  2        12
# 5689            22                  4      None
# 5690             5                  3      None
#
#                                         popular_shelves  ...  \
# 0     [to-read, currently-reading, mystery, lisa-gar...  ...
# 1     [to-read, currently-reading, james-patterson, ...  ...
# 2     [to-read, currently-reading, fiction, mystery,...  ...
# 3     [to-read, currently-reading, fiction, favorite...  ...
# 4     [to-read, currently-reading, fiction, mystery,...  ...
# ...                                                 ...  ...
# 5686                                                NaN  ...
# 5687                                                NaN  ...
# 5688                                                NaN  ...
# 5689                                                NaN  ...
# 5690                                                NaN  ...
#
#                                                    link bestseller   5-star  \
# 0     https://www.goodreads.com/book/show/7361506-alone          1    15893
# 1     https://www.goodreads.com/book/show/10130768-t...          1     8334
# 2     https://www.goodreads.com/book/show/6620989-th...          1  1136433
# 3     https://www.goodreads.com/book/show/7654769-wa...          1   528848
# 4     https://www.goodreads.com/book/show/6652906-th...          1   350054
# ...                                                 ...        ...      ...
# 5686  https://www.goodreads.com/book/show/18123696-t...          0      268
# 5687  https://www.goodreads.com/book/show/18100299-d...          0      368
# 5688  https://www.goodreads.com/book/show/13529366-b...          0      379
# 5689  https://www.goodreads.com/book/show/31806710-d...          0     1162
# 5690  https://www.goodreads.com/book/show/36647211-s...          0     5564
#
#       4-star  3-star  2-star 1-star    total  \
# 0      21149   11622    2035    696    51395
# 1       9946    4980     783    172    24215
# 2     845761  355379  106672  75936  2520181
# 3     499656  236299   57872  19760  1342435
# 4     307130  106664   18618   6123   788589
# ...      ...     ...     ...    ...      ...
# 5686     405     247      36      7      963
# 5687     414     148      15      4      949
# 5688    1099    1501     708    270     3957
# 5689    1092     518      91     22     2885
# 5690    4517    1720     390    291    12482
#
#                              word_tokenized_description  \
# 0     [bonus, this, edition, includes, the, full, te...
# 1     [nyc, s, detective, michael, bennett, has, a, ...
# 2     [a, spellbinding, amalgam, of, murder, mystery...
# 3     [over, copies, in, print, worldwide, new, york...
# 4     [part, blistering, espionage, thriller, part, ...
# ...                                                 ...
# 5686  [burton, swinburne, return, in, a, new, series...
# 5687  [repairman, jack, is, one, of, my, favorite, c...
# 5688  [critically, celebrated, novelist, scott, spen...
# 5689  [hours, minutesan, immortal, warrior, must, de...
# 5690  [from, the, wall, street, journal, bestselling...
#
#                                  lemmatized_description
# 0     bonus this edition include the full text of th...
# 1     nyc s detective michael bennett ha a huge prob...
# 2     a spellbind amalgam of murder mystery family s...
# 3     over copy in print worldwide new york time bes...
# 4     part blister espionage thriller part rivet pol...
# ...                                                 ...
# 5686  burton swinburne return in a new series the be...
# 5687  repairman jack be one of my favorite character...
# 5688  critically celebrate novelist scott spencer de...
# 5689  hour minutesan immortal warrior must decide be...
# 5690  from the wall street journal bestselling autho...
#
# [8560 rows x 26 columns]

# %%
all_books.to_pickle('all_books.pkl')
